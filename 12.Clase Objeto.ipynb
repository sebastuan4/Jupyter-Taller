# %%
class persona():
    colorOjos="cafe"
    altura=1.75
    colorPelo="negro"
    estado="Despierto"

    def dormido():
        persona.estado="Dormido"
        return persona.estado

# %%
print(persona.estado)
persona.dormido()
# Out:
# Despierto
# 'Dormido'
