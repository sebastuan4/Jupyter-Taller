# %%
#Ayudan a buscar texto donde sea!
#Busqueda de existencia o coincidencia de texto
import re
string="""
Don Quijote de la Mancha es una novela escrita por el español Miguel de Cervantes Saavedra. 
Publicada su primera parte con el título de El ingenioso hidalgo don Quijote de la Mancha a
comienzos de 1605, es la obra más destacada de la literatura española y una de las principales 
de la literatura universal, además de ser la más leída después de la Biblia.
En 1615 apareció su continuación con el título de Segunda parte del ingenioso caballero
don Quijote de la Mancha. El Quijote de 1605 se publicó dividido en cuatro partes;
pero al aparecer el Quijote de 1615 en calidad de Segunda parte de la obra, 
quedó revocada de hecho la partición en cuatro secciones del volumen publicado 
diez años antes por Cervantes.
"""
print(re.search("Mancha",string))
# Out:
# <re.Match object; span=(19, 25), match='Mancha'>

# %%
#Patrones de busqueda
import re
string="""
Don Quijote de la Mancha es una novela escrita por el español Miguel de Cervantes Saavedra. 
Publicada su primera parte con el título de El ingenioso hidalgo don Quijote de la Mancha a
comienzos de 1605, es la obra más destacada de la literatura española y una de las principales 
de la literatura universal, además de ser la más leída después de la Biblia.
En 1615 apareció su continuación con el título de Segunda parte del ingenioso caballero
don Quijote de la Mancha. El Quijote de 1605 se publicó dividido en cuatro partes;
pero al aparecer el Quijote de 1615 en calidad de Segunda parte de la obra, 
quedó revocada de hecho la partición en cuatro secciones del volumen publicado 
diez años antes por Cervantes.
"""
print(re.search("Mancha",string))
print(re.search("Casa",string))
print(re.findall("Mancha",string))
print(len(re.findall("Mancha",string)))
# Out:
# <re.Match object; span=(19, 25), match='Mancha'>
# None
# ['Mancha', 'Mancha', 'Mancha']
# 3

# %%
import re
paises = ['Japan', 'Indonesia', 'India', 'Philippines', 'Brazil',
       'South Korea', 'Mexico', 'Egypt', 'United States', 'Russia',
       'Thailand', 'Bangladesh', 'Argentina', 'Nigeria', 'Turkey',
       'Pakistan', 'Congo (Kinshasa)', 'Vietnam', 'Iran',
       'United Kingdom', 'France', 'Peru', 'Angola', 'Malaysia',
       'Colombia', 'Tanzania', 'Hong Kong', 'Chile', 'Saudi Arabia',
       'Iraq', 'Sudan', 'Spain', 'Kenya', 'Myanmar', 'Canada',
       'Singapore', "Côte d'Ivoire", 'Australia', 'South Africa',
       'Morocco', 'Afghanistan', 'Jordan', 'Germany', 'Algeria',
       'Bolivia', 'Ethiopia', 'Kuwait', 'Ukraine', 'Yemen', 'Guatemala',
       'Italy', 'North Korea', 'Taiwan', 'Ecuador', 'Madagascar',
       'Dominican Republic', 'United Arab Emirates', 'Uzbekistan',
       'Burkina Faso', 'Cameroon', 'Ghana', 'Azerbaijan', 'Zimbabwe',
       'Cuba', 'Cambodia', 'Somalia', 'Mali', 'Belarus', 'Venezuela',
       'Syria', 'Kazakhstan', 'Austria', 'Malawi', 'Romania',
       'Congo (Brazzaville)', 'Poland', 'Belgium', 'Zambia', 'Hungary',
       'Guinea', 'Uganda', 'Oman', 'Mongolia', 'Serbia', 'New Zealand',
       'Czechia', 'Uruguay', 'Bulgaria', 'Honduras', 'Mozambique',
       'Qatar', 'Senegal', 'Rwanda', 'Libya', 'Georgia', 'Chad',
       'Denmark', 'Armenia', 'Mauritania', 'Kyrgyzstan', 'Tunisia',
       'Nepal', 'Niger', 'Nicaragua', 'Liberia', 'Haiti', 'Sweden',
       'Eritrea', 'Sierra Leone', 'Laos', 'Israel',
       'Central African Republic', 'Panama', 'Netherlands', 'Togo',
       'Gabon', 'Croatia', 'Tajikistan', 'Benin', 'Sri Lanka', 'Norway',
       'Greece', 'Burundi', 'Finland', 'Macedonia', 'Moldova', 'Latvia',
       'Jamaica', 'Lithuania', 'El Salvador', 'Djibouti', 'Ireland',
       'Paraguay', 'Portugal', 'Slovakia', 'Estonia', 'Lebanon',
       'Albania', 'Guinea-Bissau', 'South Sudan', 'Lesotho', 'Cyprus',
       'Namibia', 'Papua New Guinea', 'Costa Rica', 'Slovenia',
       'Bosnia And Herzegovina', 'The Bahamas', 'Martinique', 'Botswana',
       'Suriname', 'Timor-Leste', 'Maldives', 'Guyana', 'Gibraltar',
       'Reunion', 'Equatorial Guinea', 'Montenegro', 'Bahrain',
       'Mauritius', 'Curaçao', 'Switzerland', 'French Polynesia',
       'Luxembourg', 'Iceland', 'Cabo Verde', 'Barbados', 'Comoros',
       'Bhutan', 'Swaziland', 'New Caledonia', 'Solomon Islands', 'Fiji',
       'Saint Lucia', 'French Guiana', 'Sao Tome And Principe', 'Vanuatu',
       'Bermuda', 'Brunei', 'Monaco', 'Trinidad And Tobago', 'Samoa',
       'Kiribati', 'Aruba', 'Jersey', 'The Gambia', 'Mayotte',
       'Marshall Islands', 'Isle Of Man', 'Cayman Islands', 'Seychelles',
       'Saint Vincent And The Grenadines', 'Andorra',
       'Antigua And Barbuda', 'Tonga', 'Turkmenistan', 'Greenland',
       'Belize', 'Dominica', 'Saint Kitts And Nevis', 'Faroe Islands',
       'American Samoa', 'Malta', 'Gaza Strip',
       'Turks And Caicos Islands', 'Federated States of Micronesia',
       'Tuvalu', 'Liechtenstein', 'Cook Islands', 'Grenada', 'San Marino',
       'West Bank', 'Northern Mariana Islands',
       'Falkland Islands (Islas Malvinas)', 'Vatican City', 'Niue',
       'Guadeloupe', 'Guam', 'Saint Martin',
       'Saint Helena, Ascension, And Tristan Da Cunha', 'Montserrat',
       'Sint Maarten', 'Nauru', 'Kosovo', 'Saint Barthelemy',
       'British Virgin Islands', 'Palau', 'Saint Pierre And Miquelon',
       'Anguilla', 'Wallis And Futuna', 'Norfolk Island', 'Svalbard',
       'Pitcairn Islands', 'Christmas Island',
       'South Georgia And South Sandwich Islands', 'Macau', 'Puerto Rico',
       'U.S. Virgin Islands']
for paises in paises:
    if re.findall(".a",paises): #^ Inicie con algo $Termina con algo, [AH] Palabras a buscar, [A-B] Rango, .x cualquier palabra y que termine con algo
        print(paises)
# Out:
# Japan
# Brazil
# United States
# Thailand
# Bangladesh
# Pakistan
# Congo (Kinshasa)
# Vietnam
# Iran
# France
# Malaysia
# Tanzania
# Saudi Arabia
# Iraq
# Sudan
# Spain
# Myanmar
# Canada
# Singapore
# Australia
# Afghanistan
# Jordan
# Germany
# Kuwait
# Ukraine
# Guatemala
# Italy
# Taiwan
# Ecuador
# Madagascar
# Dominican Republic
# United Arab Emirates
# Uzbekistan
# Burkina Faso
# Cameroon
# Ghana
# Azerbaijan
# Zimbabwe
# Cambodia
# Somalia
# Mali
# Belarus
# Kazakhstan
# Malawi
# Romania
# Congo (Brazzaville)
# Poland
# Zambia
# Hungary
# Uganda
# Oman
# New Zealand
# Uruguay
# Bulgaria
# Honduras
# Mozambique
# Qatar
# Senegal
# Rwanda
# Chad
# Denmark
# Mauritania
# Kyrgyzstan
# Nepal
# Nicaragua
# Haiti
# Sierra Leone
# Laos
# Israel
# Central African Republic
# Panama
# Netherlands
# Gabon
# Croatia
# Tajikistan
# Sri Lanka
# Norway
# Finland
# Macedonia
# Latvia
# Jamaica
# Lithuania
# El Salvador
# Ireland
# Paraguay
# Portugal
# Slovakia
# Lebanon
# Albania
# Guinea-Bissau
# South Sudan
# Namibia
# Papua New Guinea
# Costa Rica
# Bosnia And Herzegovina
# The Bahamas
# Martinique
# Botswana
# Suriname
# Maldives
# Guyana
# Gibraltar
# Equatorial Guinea
# Bahrain
# Mauritius
# Curaçao
# Switzerland
# Iceland
# Cabo Verde
# Barbados
# Bhutan
# Swaziland
# New Caledonia
# Solomon Islands
# Saint Lucia
# French Guiana
# Sao Tome And Principe
# Vanuatu
# Monaco
# Trinidad And Tobago
# Samoa
# Kiribati
# The Gambia
# Mayotte
# Marshall Islands
# Isle Of Man
# Cayman Islands
# Saint Vincent And The Grenadines
# Antigua And Barbuda
# Turkmenistan
# Greenland
# Saint Kitts And Nevis
# Faroe Islands
# American Samoa
# Malta
# Gaza Strip
# Turks And Caicos Islands
# Federated States of Micronesia
# Tuvalu
# Cook Islands
# Grenada
# San Marino
# West Bank
# Northern Mariana Islands
# Falkland Islands (Islas Malvinas)
# Vatican City
# Guadeloupe
# Guam
# Saint Martin
# Saint Helena, Ascension, And Tristan Da Cunha
# Montserrat
# Sint Maarten
# Nauru
# Saint Barthelemy
# British Virgin Islands
# Palau
# Saint Pierre And Miquelon
# Wallis And Futuna
# Norfolk Island
# Svalbard
# Pitcairn Islands
# Christmas Island
# South Georgia And South Sandwich Islands
# Macau
# U.S. Virgin Islands

# %%
import re
paises = ['Japan', 'Indonesia', 'India', 'Philippines', 'Brazil',
       'South Korea', 'Mexico', 'Egypt', 'United States', 'Russia',
       'Thailand', 'Bangladesh', 'Argentina', 'Nigeria', 'Turkey',
       'Pakistan', 'Congo (Kinshasa)', 'Vietnam', 'Iran',
       'United Kingdom', 'France', 'Peru', 'Angola', 'Malaysia',
       'Colombia', 'Tanzania', 'Hong Kong', 'Chile', 'Saudi Arabia',
       'Iraq', 'Sudan', 'Spain', 'Kenya', 'Myanmar', 'Canada',
       'Singapore', "Côte d'Ivoire", 'Australia', 'South Africa',
       'Morocco', 'Afghanistan', 'Jordan', 'Germany', 'Algeria',
       'Bolivia', 'Ethiopia', 'Kuwait', 'Ukraine', 'Yemen', 'Guatemala',
       'Italy', 'North Korea', 'Taiwan', 'Ecuador', 'Madagascar',
       'Dominican Republic', 'United Arab Emirates', 'Uzbekistan',
       'Burkina Faso', 'Cameroon', 'Ghana', 'Azerbaijan', 'Zimbabwe',
       'Cuba', 'Cambodia', 'Somalia', 'Mali', 'Belarus', 'Venezuela',
       'Syria', 'Kazakhstan', 'Austria', 'Malawi', 'Romania',
       'Congo (Brazzaville)', 'Poland', 'Belgium', 'Zambia', 'Hungary',
       'Guinea', 'Uganda', 'Oman', 'Mongolia', 'Serbia', 'New Zealand',
       'Czechia', 'Uruguay', 'Bulgaria', 'Honduras', 'Mozambique',
       'Qatar', 'Senegal', 'Rwanda', 'Libya', 'Georgia', 'Chad',
       'Denmark', 'Armenia', 'Mauritania', 'Kyrgyzstan', 'Tunisia',
       'Nepal', 'Niger', 'Nicaragua', 'Liberia', 'Haiti', 'Sweden',
       'Eritrea', 'Sierra Leone', 'Laos', 'Israel',
       'Central African Republic', 'Panama', 'Netherlands', 'Togo',
       'Gabon', 'Croatia', 'Tajikistan', 'Benin', 'Sri Lanka', 'Norway',
       'Greece', 'Burundi', 'Finland', 'Macedonia', 'Moldova', 'Latvia',
       'Jamaica', 'Lithuania', 'El Salvador', 'Djibouti', 'Ireland',
       'Paraguay', 'Portugal', 'Slovakia', 'Estonia', 'Lebanon',
       'Albania', 'Guinea-Bissau', 'South Sudan', 'Lesotho', 'Cyprus',
       'Namibia', 'Papua New Guinea', 'Costa Rica', 'Slovenia',
       'Bosnia And Herzegovina', 'The Bahamas', 'Martinique', 'Botswana',
       'Suriname', 'Timor-Leste', 'Maldives', 'Guyana', 'Gibraltar',
       'Reunion', 'Equatorial Guinea', 'Montenegro', 'Bahrain',
       'Mauritius', 'Curaçao', 'Switzerland', 'French Polynesia',
       'Luxembourg', 'Iceland', 'Cabo Verde', 'Barbados', 'Comoros',
       'Bhutan', 'Swaziland', 'New Caledonia', 'Solomon Islands', 'Fiji',
       'Saint Lucia', 'French Guiana', 'Sao Tome And Principe', 'Vanuatu',
       'Bermuda', 'Brunei', 'Monaco', 'Trinidad And Tobago', 'Samoa',
       'Kiribati', 'Aruba', 'Jersey', 'The Gambia', 'Mayotte',
       'Marshall Islands', 'Isle Of Man', 'Cayman Islands', 'Seychelles',
       'Saint Vincent And The Grenadines', 'Andorra',
       'Antigua And Barbuda', 'Tonga', 'Turkmenistan', 'Greenland',
       'Belize', 'Dominica', 'Saint Kitts And Nevis', 'Faroe Islands',
       'American Samoa', 'Malta', 'Gaza Strip',
       'Turks And Caicos Islands', 'Federated States of Micronesia',
       'Tuvalu', 'Liechtenstein', 'Cook Islands', 'Grenada', 'San Marino',
       'West Bank', 'Northern Mariana Islands',
       'Falkland Islands (Islas Malvinas)', 'Vatican City', 'Niue',
       'Guadeloupe', 'Guam', 'Saint Martin',
       'Saint Helena, Ascension, And Tristan Da Cunha', 'Montserrat',
       'Sint Maarten', 'Nauru', 'Kosovo', 'Saint Barthelemy',
       'British Virgin Islands', 'Palau', 'Saint Pierre And Miquelon',
       'Anguilla', 'Wallis And Futuna', 'Norfolk Island', 'Svalbard',
       'Pitcairn Islands', 'Christmas Island',
       'South Georgia And South Sandwich Islands', 'Macau', 'Puerto Rico',
       'U.S. Virgin Islands']
for paises in paises:
    if re.findall("sia$",paises):
        print(paises)

# %%
import re
paises = ['Japan', 'Indonesia', 'India', 'Philippines', 'Brazil',
       'South Korea', 'Mexico', 'Egypt', 'United States', 'Russia',
       'Thailand', 'Bangladesh', 'Argentina', 'Nigeria', 'Turkey',
       'Pakistan', 'Congo (Kinshasa)', 'Vietnam', 'Iran',
       'United Kingdom', 'France', 'Peru', 'Angola', 'Malaysia',
       'Colombia', 'Tanzania', 'Hong Kong', 'Chile', 'Saudi Arabia',
       'Iraq', 'Sudan', 'Spain', 'Kenya', 'Myanmar', 'Canada',
       'Singapore', "Côte d'Ivoire", 'Australia', 'South Africa',
       'Morocco', 'Afghanistan', 'Jordan', 'Germany', 'Algeria',
       'Bolivia', 'Ethiopia', 'Kuwait', 'Ukraine', 'Yemen', 'Guatemala',
       'Italy', 'North Korea', 'Taiwan', 'Ecuador', 'Madagascar',
       'Dominican Republic', 'United Arab Emirates', 'Uzbekistan',
       'Burkina Faso', 'Cameroon', 'Ghana', 'Azerbaijan', 'Zimbabwe',
       'Cuba', 'Cambodia', 'Somalia', 'Mali', 'Belarus', 'Venezuela',
       'Syria', 'Kazakhstan', 'Austria', 'Malawi', 'Romania',
       'Congo (Brazzaville)', 'Poland', 'Belgium', 'Zambia', 'Hungary',
       'Guinea', 'Uganda', 'Oman', 'Mongolia', 'Serbia', 'New Zealand',
       'Czechia', 'Uruguay', 'Bulgaria', 'Honduras', 'Mozambique',
       'Qatar', 'Senegal', 'Rwanda', 'Libya', 'Georgia', 'Chad',
       'Denmark', 'Armenia', 'Mauritania', 'Kyrgyzstan', 'Tunisia',
       'Nepal', 'Niger', 'Nicaragua', 'Liberia', 'Haiti', 'Sweden',
       'Eritrea', 'Sierra Leone', 'Laos', 'Israel',
       'Central African Republic', 'Panama', 'Netherlands', 'Togo',
       'Gabon', 'Croatia', 'Tajikistan', 'Benin', 'Sri Lanka', 'Norway',
       'Greece', 'Burundi', 'Finland', 'Macedonia', 'Moldova', 'Latvia',
       'Jamaica', 'Lithuania', 'El Salvador', 'Djibouti', 'Ireland',
       'Paraguay', 'Portugal', 'Slovakia', 'Estonia', 'Lebanon',
       'Albania', 'Guinea-Bissau', 'South Sudan', 'Lesotho', 'Cyprus',
       'Namibia', 'Papua New Guinea', 'Costa Rica', 'Slovenia',
       'Bosnia And Herzegovina', 'The Bahamas', 'Martinique', 'Botswana',
       'Suriname', 'Timor-Leste', 'Maldives', 'Guyana', 'Gibraltar',
       'Reunion', 'Equatorial Guinea', 'Montenegro', 'Bahrain',
       'Mauritius', 'Curaçao', 'Switzerland', 'French Polynesia',
       'Luxembourg', 'Iceland', 'Cabo Verde', 'Barbados', 'Comoros',
       'Bhutan', 'Swaziland', 'New Caledonia', 'Solomon Islands', 'Fiji',
       'Saint Lucia', 'French Guiana', 'Sao Tome And Principe', 'Vanuatu',
       'Bermuda', 'Brunei', 'Monaco', 'Trinidad And Tobago', 'Samoa',
       'Kiribati', 'Aruba', 'Jersey', 'The Gambia', 'Mayotte',
       'Marshall Islands', 'Isle Of Man', 'Cayman Islands', 'Seychelles',
       'Saint Vincent And The Grenadines', 'Andorra',
       'Antigua And Barbuda', 'Tonga', 'Turkmenistan', 'Greenland',
       'Belize', 'Dominica', 'Saint Kitts And Nevis', 'Faroe Islands',
       'American Samoa', 'Malta', 'Gaza Strip',
       'Turks And Caicos Islands', 'Federated States of Micronesia',
       'Tuvalu', 'Liechtenstein', 'Cook Islands', 'Grenada', 'San Marino',
       'West Bank', 'Northern Mariana Islands',
       'Falkland Islands (Islas Malvinas)', 'Vatican City', 'Niue',
       'Guadeloupe', 'Guam', 'Saint Martin',
       'Saint Helena, Ascension, And Tristan Da Cunha', 'Montserrat',
       'Sint Maarten', 'Nauru', 'Kosovo', 'Saint Barthelemy',
       'British Virgin Islands', 'Palau', 'Saint Pierre And Miquelon',
       'Anguilla', 'Wallis And Futuna', 'Norfolk Island', 'Svalbard',
       'Pitcairn Islands', 'Christmas Island',
       'South Georgia And South Sandwich Islands', 'Macau', 'Puerto Rico',
       'U.S. Virgin Islands']
for paises in paises:
    if re.findall("[lh]",paises):
        print(paises)

# %%
import re
paises = ['Japan', 'Indonesia', 'India', 'Philippines', 'Brazil',
       'South Korea', 'Mexico', 'Egypt', 'United States', 'Russia',
       'Thailand', 'Bangladesh', 'Argentina', 'Nigeria', 'Turkey',
       'Pakistan', 'Congo (Kinshasa)', 'Vietnam', 'Iran',
       'United Kingdom', 'France', 'Peru', 'Angola', 'Malaysia',
       'Colombia', 'Tanzania', 'Hong Kong', 'Chile', 'Saudi Arabia',
       'Iraq', 'Sudan', 'Spain', 'Kenya', 'Myanmar', 'Canada',
       'Singapore', "Côte d'Ivoire", 'Australia', 'South Africa',
       'Morocco', 'Afghanistan', 'Jordan', 'Germany', 'Algeria',
       'Bolivia', 'Ethiopia', 'Kuwait', 'Ukraine', 'Yemen', 'Guatemala',
       'Italy', 'North Korea', 'Taiwan', 'Ecuador', 'Madagascar',
       'Dominican Republic', 'United Arab Emirates', 'Uzbekistan',
       'Burkina Faso', 'Cameroon', 'Ghana', 'Azerbaijan', 'Zimbabwe',
       'Cuba', 'Cambodia', 'Somalia', 'Mali', 'Belarus', 'Venezuela',
       'Syria', 'Kazakhstan', 'Austria', 'Malawi', 'Romania',
       'Congo (Brazzaville)', 'Poland', 'Belgium', 'Zambia', 'Hungary',
       'Guinea', 'Uganda', 'Oman', 'Mongolia', 'Serbia', 'New Zealand',
       'Czechia', 'Uruguay', 'Bulgaria', 'Honduras', 'Mozambique',
       'Qatar', 'Senegal', 'Rwanda', 'Libya', 'Georgia', 'Chad',
       'Denmark', 'Armenia', 'Mauritania', 'Kyrgyzstan', 'Tunisia',
       'Nepal', 'Niger', 'Nicaragua', 'Liberia', 'Haiti', 'Sweden',
       'Eritrea', 'Sierra Leone', 'Laos', 'Israel',
       'Central African Republic', 'Panama', 'Netherlands', 'Togo',
       'Gabon', 'Croatia', 'Tajikistan', 'Benin', 'Sri Lanka', 'Norway',
       'Greece', 'Burundi', 'Finland', 'Macedonia', 'Moldova', 'Latvia',
       'Jamaica', 'Lithuania', 'El Salvador', 'Djibouti', 'Ireland',
       'Paraguay', 'Portugal', 'Slovakia', 'Estonia', 'Lebanon',
       'Albania', 'Guinea-Bissau', 'South Sudan', 'Lesotho', 'Cyprus',
       'Namibia', 'Papua New Guinea', 'Costa Rica', 'Slovenia',
       'Bosnia And Herzegovina', 'The Bahamas', 'Martinique', 'Botswana',
       'Suriname', 'Timor-Leste', 'Maldives', 'Guyana', 'Gibraltar',
       'Reunion', 'Equatorial Guinea', 'Montenegro', 'Bahrain',
       'Mauritius', 'Curaçao', 'Switzerland', 'French Polynesia',
       'Luxembourg', 'Iceland', 'Cabo Verde', 'Barbados', 'Comoros',
       'Bhutan', 'Swaziland', 'New Caledonia', 'Solomon Islands', 'Fiji',
       'Saint Lucia', 'French Guiana', 'Sao Tome And Principe', 'Vanuatu',
       'Bermuda', 'Brunei', 'Monaco', 'Trinidad And Tobago', 'Samoa',
       'Kiribati', 'Aruba', 'Jersey', 'The Gambia', 'Mayotte',
       'Marshall Islands', 'Isle Of Man', 'Cayman Islands', 'Seychelles',
       'Saint Vincent And The Grenadines', 'Andorra',
       'Antigua And Barbuda', 'Tonga', 'Turkmenistan', 'Greenland',
       'Belize', 'Dominica', 'Saint Kitts And Nevis', 'Faroe Islands',
       'American Samoa', 'Malta', 'Gaza Strip',
       'Turks And Caicos Islands', 'Federated States of Micronesia',
       'Tuvalu', 'Liechtenstein', 'Cook Islands', 'Grenada', 'San Marino',
       'West Bank', 'Northern Mariana Islands',
       'Falkland Islands (Islas Malvinas)', 'Vatican City', 'Niue',
       'Guadeloupe', 'Guam', 'Saint Martin',
       'Saint Helena, Ascension, And Tristan Da Cunha', 'Montserrat',
       'Sint Maarten', 'Nauru', 'Kosovo', 'Saint Barthelemy',
       'British Virgin Islands', 'Palau', 'Saint Pierre And Miquelon',
       'Anguilla', 'Wallis And Futuna', 'Norfolk Island', 'Svalbard',
       'Pitcairn Islands', 'Christmas Island',
       'South Georgia And South Sandwich Islands', 'Macau', 'Puerto Rico',
       'U.S. Virgin Islands']
for paises in paises:
    if re.findall("[a-c]",paises):
        print(paises)

# %%
import re
paises = ['Japan', 'Indonesia', 'India', 'Philippines', 'Brazil',
       'South Korea', 'Mexico', 'Egypt', 'United States', 'Russia',
       'Thailand', 'Bangladesh', 'Argentina', 'Nigeria', 'Turkey',
       'Pakistan', 'Congo (Kinshasa)', 'Vietnam', 'Iran',
       'United Kingdom', 'France', 'Peru', 'Angola', 'Malaysia',
       'Colombia', 'Tanzania', 'Hong Kong', 'Chile', 'Saudi Arabia',
       'Iraq', 'Sudan', 'Spain', 'Kenya', 'Myanmar', 'Canada',
       'Singapore', "Côte d'Ivoire", 'Australia', 'South Africa',
       'Morocco', 'Afghanistan', 'Jordan', 'Germany', 'Algeria',
       'Bolivia', 'Ethiopia', 'Kuwait', 'Ukraine', 'Yemen', 'Guatemala',
       'Italy', 'North Korea', 'Taiwan', 'Ecuador', 'Madagascar',
       'Dominican Republic', 'United Arab Emirates', 'Uzbekistan',
       'Burkina Faso', 'Cameroon', 'Ghana', 'Azerbaijan', 'Zimbabwe',
       'Cuba', 'Cambodia', 'Somalia', 'Mali', 'Belarus', 'Venezuela',
       'Syria', 'Kazakhstan', 'Austria', 'Malawi', 'Romania',
       'Congo (Brazzaville)', 'Poland', 'Belgium', 'Zambia', 'Hungary',
       'Guinea', 'Uganda', 'Oman', 'Mongolia', 'Serbia', 'New Zealand',
       'Czechia', 'Uruguay', 'Bulgaria', 'Honduras', 'Mozambique',
       'Qatar', 'Senegal', 'Rwanda', 'Libya', 'Georgia', 'Chad',
       'Denmark', 'Armenia', 'Mauritania', 'Kyrgyzstan', 'Tunisia',
       'Nepal', 'Niger', 'Nicaragua', 'Liberia', 'Haiti', 'Sweden',
       'Eritrea', 'Sierra Leone', 'Laos', 'Israel',
       'Central African Republic', 'Panama', 'Netherlands', 'Togo',
       'Gabon', 'Croatia', 'Tajikistan', 'Benin', 'Sri Lanka', 'Norway',
       'Greece', 'Burundi', 'Finland', 'Macedonia', 'Moldova', 'Latvia',
       'Jamaica', 'Lithuania', 'El Salvador', 'Djibouti', 'Ireland',
       'Paraguay', 'Portugal', 'Slovakia', 'Estonia', 'Lebanon',
       'Albania', 'Guinea-Bissau', 'South Sudan', 'Lesotho', 'Cyprus',
       'Namibia', 'Papua New Guinea', 'Costa Rica', 'Slovenia',
       'Bosnia And Herzegovina', 'The Bahamas', 'Martinique', 'Botswana',
       'Suriname', 'Timor-Leste', 'Maldives', 'Guyana', 'Gibraltar',
       'Reunion', 'Equatorial Guinea', 'Montenegro', 'Bahrain',
       'Mauritius', 'Curaçao', 'Switzerland', 'French Polynesia',
       'Luxembourg', 'Iceland', 'Cabo Verde', 'Barbados', 'Comoros',
       'Bhutan', 'Swaziland', 'New Caledonia', 'Solomon Islands', 'Fiji',
       'Saint Lucia', 'French Guiana', 'Sao Tome And Principe', 'Vanuatu',
       'Bermuda', 'Brunei', 'Monaco', 'Trinidad And Tobago', 'Samoa',
       'Kiribati', 'Aruba', 'Jersey', 'The Gambia', 'Mayotte',
       'Marshall Islands', 'Isle Of Man', 'Cayman Islands', 'Seychelles',
       'Saint Vincent And The Grenadines', 'Andorra',
       'Antigua And Barbuda', 'Tonga', 'Turkmenistan', 'Greenland',
       'Belize', 'Dominica', 'Saint Kitts And Nevis', 'Faroe Islands',
       'American Samoa', 'Malta', 'Gaza Strip',
       'Turks And Caicos Islands', 'Federated States of Micronesia',
       'Tuvalu', 'Liechtenstein', 'Cook Islands', 'Grenada', 'San Marino',
       'West Bank', 'Northern Mariana Islands',
       'Falkland Islands (Islas Malvinas)', 'Vatican City', 'Niue',
       'Guadeloupe', 'Guam', 'Saint Martin',
       'Saint Helena, Ascension, And Tristan Da Cunha', 'Montserrat',
       'Sint Maarten', 'Nauru', 'Kosovo', 'Saint Barthelemy',
       'British Virgin Islands', 'Palau', 'Saint Pierre And Miquelon',
       'Anguilla', 'Wallis And Futuna', 'Norfolk Island', 'Svalbard',
       'Pitcairn Islands', 'Christmas Island',
       'South Georgia And South Sandwich Islands', 'Macau', 'Puerto Rico',
       'U.S. Virgin Islands']
for paises in paises:
    if re.findall("^[h-l]",paises,re.IGNORECASE):
        print(paises)

# %%
import re
paises = ['Japan', 'Indonesia', 'India', 'Philippines', 'Brazil',
       'South Korea', 'Mexico', 'Egypt', 'United States', 'Russia',
       'Thailand', 'Bangladesh', 'Argentina', 'Nigeria', 'Turkey',
       'Pakistan', 'Congo (Kinshasa)', 'Vietnam', 'Iran',
       'United Kingdom', 'France', 'Peru', 'Angola', 'Malaysia',
       'Colombia', 'Tanzania', 'Hong Kong', 'Chile', 'Saudi Arabia',
       'Iraq', 'Sudan', 'Spain', 'Kenya', 'Myanmar', 'Canada',
       'Singapore', "Côte d'Ivoire", 'Australia', 'South Africa',
       'Morocco', 'Afghanistan', 'Jordan', 'Germany', 'Algeria',
       'Bolivia', 'Ethiopia', 'Kuwait', 'Ukraine', 'Yemen', 'Guatemala',
       'Italy', 'North Korea', 'Taiwan', 'Ecuador', 'Madagascar',
       'Dominican Republic', 'United Arab Emirates', 'Uzbekistan',
       'Burkina Faso', 'Cameroon', 'Ghana', 'Azerbaijan', 'Zimbabwe',
       'Cuba', 'Cambodia', 'Somalia', 'Mali', 'Belarus', 'Venezuela',
       'Syria', 'Kazakhstan', 'Austria', 'Malawi', 'Romania',
       'Congo (Brazzaville)', 'Poland', 'Belgium', 'Zambia', 'Hungary',
       'Guinea', 'Uganda', 'Oman', 'Mongolia', 'Serbia', 'New Zealand',
       'Czechia', 'Uruguay', 'Bulgaria', 'Honduras', 'Mozambique',
       'Qatar', 'Senegal', 'Rwanda', 'Libya', 'Georgia', 'Chad',
       'Denmark', 'Armenia', 'Mauritania', 'Kyrgyzstan', 'Tunisia',
       'Nepal', 'Niger', 'Nicaragua', 'Liberia', 'Haiti', 'Sweden',
       'Eritrea', 'Sierra Leone', 'Laos', 'Israel',
       'Central African Republic', 'Panama', 'Netherlands', 'Togo',
       'Gabon', 'Croatia', 'Tajikistan', 'Benin', 'Sri Lanka', 'Norway',
       'Greece', 'Burundi', 'Finland', 'Macedonia', 'Moldova', 'Latvia',
       'Jamaica', 'Lithuania', 'El Salvador', 'Djibouti', 'Ireland',
       'Paraguay', 'Portugal', 'Slovakia', 'Estonia', 'Lebanon',
       'Albania', 'Guinea-Bissau', 'South Sudan', 'Lesotho', 'Cyprus',
       'Namibia', 'Papua New Guinea', 'Costa Rica', 'Slovenia',
       'Bosnia And Herzegovina', 'The Bahamas', 'Martinique', 'Botswana',
       'Suriname', 'Timor-Leste', 'Maldives', 'Guyana', 'Gibraltar',
       'Reunion', 'Equatorial Guinea', 'Montenegro', 'Bahrain',
       'Mauritius', 'Curaçao', 'Switzerland', 'French Polynesia',
       'Luxembourg', 'Iceland', 'Cabo Verde', 'Barbados', 'Comoros',
       'Bhutan', 'Swaziland', 'New Caledonia', 'Solomon Islands', 'Fiji',
       'Saint Lucia', 'French Guiana', 'Sao Tome And Principe', 'Vanuatu',
       'Bermuda', 'Brunei', 'Monaco', 'Trinidad And Tobago', 'Samoa',
       'Kiribati', 'Aruba', 'Jersey', 'The Gambia', 'Mayotte',
       'Marshall Islands', 'Isle Of Man', 'Cayman Islands', 'Seychelles',
       'Saint Vincent And The Grenadines', 'Andorra',
       'Antigua And Barbuda', 'Tonga', 'Turkmenistan', 'Greenland',
       'Belize', 'Dominica', 'Saint Kitts And Nevis', 'Faroe Islands',
       'American Samoa', 'Malta', 'Gaza Strip',
       'Turks And Caicos Islands', 'Federated States of Micronesia',
       'Tuvalu', 'Liechtenstein', 'Cook Islands', 'Grenada', 'San Marino',
       'West Bank', 'Northern Mariana Islands',
       'Falkland Islands (Islas Malvinas)', 'Vatican City', 'Niue',
       'Guadeloupe', 'Guam', 'Saint Martin',
       'Saint Helena, Ascension, And Tristan Da Cunha', 'Montserrat',
       'Sint Maarten', 'Nauru', 'Kosovo', 'Saint Barthelemy',
       'British Virgin Islands', 'Palau', 'Saint Pierre And Miquelon',
       'Anguilla', 'Wallis And Futuna', 'Norfolk Island', 'Svalbard',
       'Pitcairn Islands', 'Christmas Island',
       'South Georgia And South Sandwich Islands', 'Macau', 'Puerto Rico',
       'U.S. Virgin Islands']
for paises in paises:
    if re.findall(".sia",paises,re.IGNORECASE):
        print(paises)
