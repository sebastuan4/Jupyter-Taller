# %%
"s"/1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\sebas\Desktop\Jupyter\10.Try Expect.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sebas/Desktop/Jupyter/10.Try%20Expect.ipynb#ch0000000?line=0'>1</a> "s"/1
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
try:
    "s"/0
except ZeroDivisionError:
    print("No se puede dividir entre 0")
except:
    print("No se cual es el error pero el programa continuara")
print("El programa continua")
# Out:
# No se cual es el error pero el programa continuara
# El programa continua

# %%
try:
    #10/0
    #print("Aqui se corta")
    "text"/2
except ZeroDivisionError:
    print("No se pude dividir entre 0")
except :
    print("No se cual es el error pero el programa continuara")
print("El programa continua")
